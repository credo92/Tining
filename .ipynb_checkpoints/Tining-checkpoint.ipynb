# %%
# %matplotlib inline

from collections import Counter
from prettytable import PrettyTable
import matplotlib.pyplot as plt
import json
#Establishing Connection
import twitter
CONSUMER_KEY = 'XXXXXX'
CONSUMER_SECRET = 'XXXXX'
OAUTH_TOKEN = 'XXXXXX'
OAUTH_TOKEN_SECRET = 'XXXXXXXXXXX'
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)
print(twitter_api)

#trending topics using World Id,woeid available on yahoo 
WORLD_WOE_ID = 1
CA_WOE_ID = 23424775

#getting world trends

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
ca_trends = twitter_api.trends.place(_id=CA_WOE_ID)w

#output
# basic analysis
# using python sets to find common trending between world and india

world_trends_set = set([trend['name']
                      for trend in world_trends[0]['trends']
                       ])
ca_trends_sett = set([trend['name']
                   for trend in ca_trends[0]['trends']
                    ])
common_trends = world_trends_set.intersection(ca_trends_set)
print common_trends

print json.dumps(world_trends, indent=1)
print 
print json.dumps(ca_trends, indent=1)

## Searching statuses 

q = '#Jio'
count = 100

search_results = twitter_api.search.tweets(q=q,count=count)
statuses = search_results['statuses']

for _ in range(5):
    print "Length of statuses", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e: # nothin when next result null
        break
    #dictionary
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&")])
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']
   

    #extracting text, screen names, and hastags
    status_texts = [ status['text']
                 for status in statuses]
    screen_names = [user_mention['screen_name']
                for status in statuses
                    for user_mention in status['entities']['user_mentions']]

    hashtags = [ hashtag['text']
            for status in statuses
                for hashtag in status['entities']['hashtags']]

    # collection of words 
    words = [ w
          for t in status_texts
              for w in t.split()]

#frequency distribution from the words in tweets 
for item in [words,screen_names,hashtags]:
    c=Counter(item)
    print c.most_common()[:10] #top 10
    print

retweets  = [ 
            (status['retweet_count'],
             status['retweeted_status']['user']['screen_name'],
             status['text'])
            
            for status in statuses
                if status.has_key('retweeted_status')

            ]    
#pretty table to display tuples in a nice tabular format
#Data Visualization Frequency Data with Histograms
for label, data in(
                    ('Word', words),
                    ('Screen Name', screen_names),
                    ('Hashtag', hashtags)):
    counts = [count for count, _, _ in retweets]
    plt.hist(counts)
    plt.title("Retweets")
    plt.xlabel('Bins (number of times retweed)')
    plt.ylabel('Number of tweets in bin')
    
    print counts
    
    
    pt = PrettyTable(field_names=[label, 'Count'])
    c  = Counter(data)
    plt.hist(c.values())
    
    plt.title(label)
    plt.ylabel("Number of items in bin")
    plt.xlabel("Bins (number of times an item appeared)")
    plt.figure()
    
    [pt.add_row(kv) for kv in c.most_common()[:10]]
    pt.align[label], pt.align['Count'] = 'l', 'r' # column alignment
    print pt
    
    pt = PrettyTable(field_names=['Count','Screen Name', 'Text'])
    [ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5]]
    pt.max_width['Text'] = 50
    pt.align= 'l'
    print pt
    
    

# lexical diversity measure for tweets 

def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens)

def average_words(statuses):
    total_words = sum([len(s.split()) for s in statuses])
    return 1.0*total_words/len(statuses)

#users who have retweeted a status using statuses/retweets/:id API.
_retweets  = twitter_api.statuses.retweets(id=317127304981667841)
print [r['user']['screen_name'] for r in _retweets]
                     

                     





#printing lexical diversity Quantitative Measure

print lexical_diversity(words)
print lexical_diversity(screen_names)
print lexical_diversity(hashtags)
print average_words(status_texts)



#print sample search by slicing the list
print json.dumps(statuses[0], indent=1)    
        
#print first items
print json.dumps(status_texts[0:5], indent=1)
print json.dumps(screen_names[0:5], indent =1)
print json.dumps(hashtags[0:5], indent =1)
print json.dumps(words[0:5], indent =1)
# Out:
# <twitter.api.Twitter object at 0x10d2a21d0>
# set([u'Joe McKnight', u'#NothingSaysTheHolidaysLike'])
# [
#  {
#   "created_at": "2016-12-01T23:22:14Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23Gala13GH17",
#     "query": "%23Gala13GH17",
#     "tweet_volume": 210798,
#     "name": "#Gala13GH17",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LOS40MusicAwards",
#     "query": "%23LOS40MusicAwards",
#     "tweet_volume": 80584,
#     "name": "#LOS40MusicAwards",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23bbcqt",
#     "query": "%23bbcqt",
#     "tweet_volume": 14008,
#     "name": "#bbcqt",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23XF10",
#     "query": "%23XF10",
#     "tweet_volume": 55161,
#     "name": "#XF10",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Hollande",
#     "query": "%23Hollande",
#     "tweet_volume": 77680,
#     "name": "#Hollande",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Joe+McKnight%22",
#     "query": "%22Joe+McKnight%22",
#     "tweet_volume": 38816,
#     "name": "Joe McKnight",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Andrew+Sachs%22",
#     "query": "%22Andrew+Sachs%22",
#     "tweet_volume": 10980,
#     "name": "Andrew Sachs",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Kodak",
#     "query": "Kodak",
#     "tweet_volume": 207818,
#     "name": "Kodak",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Kevin+Wilson%22",
#     "query": "%22Kevin+Wilson%22",
#     "tweet_volume": null,
#     "name": "Kevin Wilson",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Howard+Schultz%22",
#     "query": "%22Howard+Schultz%22",
#     "tweet_volume": 10798,
#     "name": "Howard Schultz",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Carrier",
#     "query": "Carrier",
#     "tweet_volume": 364625,
#     "name": "Carrier",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Enem+2016%22",
#     "query": "%22Enem+2016%22",
#     "tweet_volume": 18215,
#     "name": "Enem 2016",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TheApprentice",
#     "query": "%23TheApprentice",
#     "tweet_volume": 20515,
#     "name": "#TheApprentice",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23pesadillaportuguesa",
#     "query": "%23pesadillaportuguesa",
#     "tweet_volume": null,
#     "name": "#pesadillaportuguesa",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%88%D8%B6%D8%B9%D9%8A_%D9%8A%D8%AA%D9%84%D8%AE%D8%A8%D8%B7_%D8%A7%D8%B0%D8%A7",
#     "query": "%23%D9%88%D8%B6%D8%B9%D9%8A_%D9%8A%D8%AA%D9%84%D8%AE%D8%A8%D8%B7_%D8%A7%D8%B0%D8%A7",
#     "tweet_volume": 26971,
#     "name": "#\u0648\u0636\u0639\u064a_\u064a\u062a\u0644\u062e\u0628\u0637_\u0627\u0630\u0627",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CamilaIsLaurenGirlfriend",
#     "query": "%23CamilaIsLaurenGirlfriend",
#     "tweet_volume": 49527,
#     "name": "#CamilaIsLaurenGirlfriend",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23BraccialettiRossi3",
#     "query": "%23BraccialettiRossi3",
#     "tweet_volume": 89904,
#     "name": "#BraccialettiRossi3",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MRSPOTATOHEADMUSICVIDEO",
#     "query": "%23MRSPOTATOHEADMUSICVIDEO",
#     "tweet_volume": null,
#     "name": "#MRSPOTATOHEADMUSICVIDEO",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Beyond",
#     "query": "%23Beyond",
#     "tweet_volume": 48955,
#     "name": "#Beyond",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23EuPrestoSim",
#     "query": "%23EuPrestoSim",
#     "tweet_volume": null,
#     "name": "#EuPrestoSim",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%8347",
#     "query": "%23%D8%B2%D8%AF_%D8%B1%D8%B5%D9%8A%D8%AF%D9%8347",
#     "tweet_volume": 189736,
#     "name": "#\u0632\u062f_\u0631\u0635\u064a\u062f\u064347",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MafiaSdvSintoFaltaDe",
#     "query": "%23MafiaSdvSintoFaltaDe",
#     "tweet_volume": 11002,
#     "name": "#MafiaSdvSintoFaltaDe",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GREENDAYENMTVHITS",
#     "query": "%23GREENDAYENMTVHITS",
#     "tweet_volume": null,
#     "name": "#GREENDAYENMTVHITS",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TBTNoTVZ",
#     "query": "%23TBTNoTVZ",
#     "tweet_volume": null,
#     "name": "#TBTNoTVZ",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D8%B2%D9%8A%D9%86_%D9%88%D8%AD%D8%AF%D9%87_%D9%85%D9%86%D9%88",
#     "query": "%23%D8%A7%D8%B2%D9%8A%D9%86_%D9%88%D8%AD%D8%AF%D9%87_%D9%85%D9%86%D9%88",
#     "tweet_volume": null,
#     "name": "#\u0627\u0632\u064a\u0646_\u0648\u062d\u062f\u0647_\u0645\u0646\u0648",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D9%88%D8%B7%D9%86%D9%8A_45",
#     "query": "%23%D8%A7%D9%84%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D9%88%D8%B7%D9%86%D9%8A_45",
#     "tweet_volume": 72503,
#     "name": "#\u0627\u0644\u064a\u0648\u0645_\u0627\u0644\u0648\u0637\u0646\u064a_45",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NothingSaysTheHolidaysLike",
#     "query": "%23NothingSaysTheHolidaysLike",
#     "tweet_volume": null,
#     "name": "#NothingSaysTheHolidaysLike",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CarinhaDeAnjo009",
#     "query": "%23CarinhaDeAnjo009",
#     "tweet_volume": 11526,
#     "name": "#CarinhaDeAnjo009",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23contraoaborto",
#     "query": "%23contraoaborto",
#     "tweet_volume": 48477,
#     "name": "#contraoaborto",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Piazzapulita",
#     "query": "%23Piazzapulita",
#     "tweet_volume": null,
#     "name": "#Piazzapulita",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B9%D9%85%D9%84_%D9%8A%D8%B3%D9%8A%D8%B1_%D9%88%D8%A7%D8%AC%D8%B1_%D8%B9%D8%B8%D9%8A%D9%85",
#     "query": "%23%D8%B9%D9%85%D9%84_%D9%8A%D8%B3%D9%8A%D8%B1_%D9%88%D8%A7%D8%AC%D8%B1_%D8%B9%D8%B8%D9%8A%D9%85",
#     "tweet_volume": 29122,
#     "name": "#\u0639\u0645\u0644_\u064a\u0633\u064a\u0631_\u0648\u0627\u062c\u0631_\u0639\u0638\u064a\u0645",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%86%D8%B5%D8%B1_%D8%A7%D9%84%D8%A8%D8%A7%D8%B7%D9%86",
#     "query": "%23%D8%A7%D9%84%D9%86%D8%B5%D8%B1_%D8%A7%D9%84%D8%A8%D8%A7%D8%B7%D9%86",
#     "tweet_volume": 193119,
#     "name": "#\u0627\u0644\u0646\u0635\u0631_\u0627\u0644\u0628\u0627\u0637\u0646",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Cyborg",
#     "query": "%23Cyborg",
#     "tweet_volume": null,
#     "name": "#Cyborg",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%234A%C3%B1osTransformandoMx",
#     "query": "%234A%C3%B1osTransformandoMx",
#     "tweet_volume": 15026,
#     "name": "#4A\u00f1osTransformandoMx",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23C%C3%BCbbeliBeyazTVde",
#     "query": "%23C%C3%BCbbeliBeyazTVde",
#     "tweet_volume": 20485,
#     "name": "#C\u00fcbbeliBeyazTVde",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MeMataQueT%C3%BA",
#     "query": "%23MeMataQueT%C3%BA",
#     "tweet_volume": 14403,
#     "name": "#MeMataQueT\u00fa",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%88%D8%B2%D8%A7%D8%B1%D9%87_%D8%A7%D9%84%D8%A7%D8%B9%D9%84%D8%A7%D9%85_%D8%AA%D9%88%D9%82%D9%81_%D9%82%D9%86%D8%A7%D9%87_bf",
#     "query": "%23%D9%88%D8%B2%D8%A7%D8%B1%D9%87_%D8%A7%D9%84%D8%A7%D8%B9%D9%84%D8%A7%D9%85_%D8%AA%D9%88%D9%82%D9%81_%D9%82%D9%86%D8%A7%D9%87_bf",
#     "tweet_volume": 25212,
#     "name": "#\u0648\u0632\u0627\u0631\u0647_\u0627\u0644\u0627\u0639\u0644\u0627\u0645_\u062a\u0648\u0642\u0641_\u0642\u0646\u0627\u0647_bf",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ExperimentoSocial",
#     "query": "%23ExperimentoSocial",
#     "tweet_volume": null,
#     "name": "#ExperimentoSocial",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GeordieShoreMTV",
#     "query": "%23GeordieShoreMTV",
#     "tweet_volume": null,
#     "name": "#GeordieShoreMTV",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SubeTusSeguidoresAqui",
#     "query": "%23SubeTusSeguidoresAqui",
#     "tweet_volume": null,
#     "name": "#SubeTusSeguidoresAqui",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D8%B0%D9%83%D8%B1%D9%8A_%D9%84%D9%8A%D9%83_%D9%85%D8%B9_%D8%A7%D9%84%D8%B4%D8%AA%D8%A7",
#     "query": "%23%D8%B0%D9%83%D8%B1%D9%8A_%D9%84%D9%8A%D9%83_%D9%85%D8%B9_%D8%A7%D9%84%D8%B4%D8%AA%D8%A7",
#     "tweet_volume": 202401,
#     "name": "#\u0630\u0643\u0631\u064a_\u0644\u064a\u0643_\u0645\u0639_\u0627\u0644\u0634\u062a\u0627",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23thevoicegr",
#     "query": "%23thevoicegr",
#     "tweet_volume": 10646,
#     "name": "#thevoicegr",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%85%D9%88%D9%82%D9%81_%D9%84%D9%86_%D8%A7%D9%86%D8%B3%D8%A7%D9%87_%D8%AF%D8%A7%D8%AE%D9%84_%D8%A7%D9%84%D8%B7%D8%A7%D9%8A%D8%B1%D9%87",
#     "query": "%23%D9%85%D9%88%D9%82%D9%81_%D9%84%D9%86_%D8%A7%D9%86%D8%B3%D8%A7%D9%87_%D8%AF%D8%A7%D8%AE%D9%84_%D8%A7%D9%84%D8%B7%D8%A7%D9%8A%D8%B1%D9%87",
#     "tweet_volume": null,
#     "name": "#\u0645\u0648\u0642\u0641_\u0644\u0646_\u0627\u0646\u0633\u0627\u0647_\u062f\u0627\u062e\u0644_\u0627\u0644\u0637\u0627\u064a\u0631\u0647",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Barcel%C3%B3Errej%C3%B3nTV3",
#     "query": "%23Barcel%C3%B3Errej%C3%B3nTV3",
#     "tweet_volume": null,
#     "name": "#Barcel\u00f3Errej\u00f3nTV3",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LaBajada",
#     "query": "%23LaBajada",
#     "tweet_volume": 19365,
#     "name": "#LaBajada",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23cosasquemeencantanenunhombre",
#     "query": "%23cosasquemeencantanenunhombre",
#     "tweet_volume": null,
#     "name": "#cosasquemeencantanenunhombre",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%87%D8%AF%D9%8A%D9%87_%D9%85%D9%88%D8%AF%D8%B1%D9%86_%D8%A8%D8%A7%D9%84%D8%A7%D8%B3_%D8%A7%D9%84%D9%8A%D9%88%D9%85_%D9%83%D8%A7%D8%B4",
#     "query": "%23%D9%87%D8%AF%D9%8A%D9%87_%D9%85%D9%88%D8%AF%D8%B1%D9%86_%D8%A8%D8%A7%D9%84%D8%A7%D8%B3_%D8%A7%D9%84%D9%8A%D9%88%D9%85_%D9%83%D8%A7%D8%B4",
#     "tweet_volume": 29163,
#     "name": "#\u0647\u062f\u064a\u0647_\u0645\u0648\u062f\u0631\u0646_\u0628\u0627\u0644\u0627\u0633_\u0627\u0644\u064a\u0648\u0645_\u0643\u0627\u0634",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23firstdates197",
#     "query": "%23firstdates197",
#     "tweet_volume": null,
#     "name": "#firstdates197",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23%D9%83%D9%84%D8%A7%D9%85_%D9%85%D8%B9%D9%84%D9%85%D9%8A%D9%86_%D8%A7%D9%84%D8%AE%D9%85%D9%8A%D8%B3",
#     "query": "%23%D9%83%D9%84%D8%A7%D9%85_%D9%85%D8%B9%D9%84%D9%85%D9%8A%D9%86_%D8%A7%D9%84%D8%AE%D9%85%D9%8A%D8%B3",
#     "tweet_volume": null,
#     "name": "#\u0643\u0644\u0627\u0645_\u0645\u0639\u0644\u0645\u064a\u0646_\u0627\u0644\u062e\u0645\u064a\u0633",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23YaEsDiciembreYOlvide",
#     "query": "%23YaEsDiciembreYOlvide",
#     "tweet_volume": null,
#     "name": "#YaEsDiciembreYOlvide",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-12-01T23:26:54Z",
#   "locations": [
#    {
#     "woeid": 1,
#     "name": "Worldwide"
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "created_at": "2016-12-01T23:22:14Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%22Air+Miles%22",
#     "query": "%22Air+Miles%22",
#     "tweet_volume": null,
#     "name": "Air Miles",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Joe+McKnight%22",
#     "query": "%22Joe+McKnight%22",
#     "tweet_volume": 38816,
#     "name": "Joe McKnight",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ERRE",
#     "query": "%23ERRE",
#     "tweet_volume": null,
#     "name": "#ERRE",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NothingSaysTheHolidaysLike",
#     "query": "%23NothingSaysTheHolidaysLike",
#     "tweet_volume": null,
#     "name": "#NothingSaysTheHolidaysLike",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ToyDriveLive",
#     "query": "%23ToyDriveLive",
#     "tweet_volume": null,
#     "name": "#ToyDriveLive",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DisruptHRTO",
#     "query": "%23DisruptHRTO",
#     "tweet_volume": null,
#     "name": "#DisruptHRTO",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Vancouver+and+Victoria%22",
#     "query": "%22Vancouver+and+Victoria%22",
#     "tweet_volume": null,
#     "name": "Vancouver and Victoria",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PassiveAggressiveFilms",
#     "query": "%23PassiveAggressiveFilms",
#     "tweet_volume": 14163,
#     "name": "#PassiveAggressiveFilms",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Fran%C3%A7ois+Hollande%22",
#     "query": "%22Fran%C3%A7ois+Hollande%22",
#     "tweet_volume": 67738,
#     "name": "Fran\u00e7ois Hollande",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Monsef",
#     "query": "Monsef",
#     "tweet_volume": null,
#     "name": "Monsef",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Stelco",
#     "query": "Stelco",
#     "tweet_volume": null,
#     "name": "Stelco",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Gronk",
#     "query": "Gronk",
#     "tweet_volume": 31499,
#     "name": "Gronk",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Squamish",
#     "query": "Squamish",
#     "tweet_volume": null,
#     "name": "Squamish",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Kodak",
#     "query": "Kodak",
#     "tweet_volume": 207818,
#     "name": "Kodak",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22J+Cole%22",
#     "query": "%22J+Cole%22",
#     "tweet_volume": 531109,
#     "name": "J Cole",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Martin+Shkreli%22",
#     "query": "%22Martin+Shkreli%22",
#     "tweet_volume": 21562,
#     "name": "Martin Shkreli",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22New+Year%22",
#     "query": "%22New+Year%22",
#     "tweet_volume": 62540,
#     "name": "New Year",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Bad+Things%22",
#     "query": "%22Bad+Things%22",
#     "tweet_volume": 103060,
#     "name": "Bad Things",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Voisey%27s+Bay%22",
#     "query": "%22Voisey%27s+Bay%22",
#     "tweet_volume": null,
#     "name": "Voisey's Bay",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Gallagher+Index%22",
#     "query": "%22Gallagher+Index%22",
#     "tweet_volume": null,
#     "name": "Gallagher Index",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Bo+Horvat%22",
#     "query": "%22Bo+Horvat%22",
#     "tweet_volume": null,
#     "name": "Bo Horvat",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Meteorological+Winter%22",
#     "query": "%22Meteorological+Winter%22",
#     "tweet_volume": null,
#     "name": "Meteorological Winter",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Rosa+Parks%22",
#     "query": "%22Rosa+Parks%22",
#     "tweet_volume": 71394,
#     "name": "Rosa Parks",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Encarnacion",
#     "query": "Encarnacion",
#     "tweet_volume": null,
#     "name": "Encarnacion",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%22Toronto+FC%22",
#     "query": "%22Toronto+FC%22",
#     "tweet_volume": 12227,
#     "name": "Toronto FC",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23influx",
#     "query": "%23influx",
#     "tweet_volume": null,
#     "name": "#influx",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23mtholidaygift",
#     "query": "%23mtholidaygift",
#     "tweet_volume": null,
#     "name": "#mtholidaygift",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23YSBSleepOUT",
#     "query": "%23YSBSleepOUT",
#     "tweet_volume": null,
#     "name": "#YSBSleepOUT",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NASCAR",
#     "query": "%23NASCAR",
#     "tweet_volume": null,
#     "name": "#NASCAR",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23EndStigma",
#     "query": "%23EndStigma",
#     "tweet_volume": null,
#     "name": "#EndStigma",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23tpapproved",
#     "query": "%23tpapproved",
#     "tweet_volume": null,
#     "name": "#tpapproved",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NHLAllStar",
#     "query": "%23NHLAllStar",
#     "tweet_volume": null,
#     "name": "#NHLAllStar",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PitMad",
#     "query": "%23PitMad",
#     "tweet_volume": null,
#     "name": "#PitMad",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GVBOT",
#     "query": "%23GVBOT",
#     "tweet_volume": null,
#     "name": "#GVBOT",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23c4lbc",
#     "query": "%23c4lbc",
#     "tweet_volume": null,
#     "name": "#c4lbc",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Badgerow",
#     "query": "%23Badgerow",
#     "tweet_volume": null,
#     "name": "#Badgerow",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HeroWorldChallenge",
#     "query": "%23HeroWorldChallenge",
#     "tweet_volume": null,
#     "name": "#HeroWorldChallenge",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SenCA",
#     "query": "%23SenCA",
#     "tweet_volume": null,
#     "name": "#SenCA",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Presidentielle2017",
#     "query": "%23Presidentielle2017",
#     "tweet_volume": null,
#     "name": "#Presidentielle2017",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23EastYork",
#     "query": "%23EastYork",
#     "tweet_volume": null,
#     "name": "#EastYork",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Blackhawks",
#     "query": "%23Blackhawks",
#     "tweet_volume": null,
#     "name": "#Blackhawks",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23NorthYork",
#     "query": "%23NorthYork",
#     "tweet_volume": null,
#     "name": "#NorthYork",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23TFCLive",
#     "query": "%23TFCLive",
#     "tweet_volume": 28647,
#     "name": "#TFCLive",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23IMFC",
#     "query": "%23IMFC",
#     "tweet_volume": null,
#     "name": "#IMFC",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Vaillancourt",
#     "query": "%23Vaillancourt",
#     "tweet_volume": null,
#     "name": "#Vaillancourt",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23December1st",
#     "query": "%23December1st",
#     "tweet_volume": null,
#     "name": "#December1st",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ThursdayThoughts",
#     "query": "%23ThursdayThoughts",
#     "tweet_volume": 58630,
#     "name": "#ThursdayThoughts",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23SAASNORTH",
#     "query": "%23SAASNORTH",
#     "tweet_volume": null,
#     "name": "#SAASNORTH",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MillennialMusicals",
#     "query": "%23MillennialMusicals",
#     "tweet_volume": 33965,
#     "name": "#MillennialMusicals",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23KinderMorgan",
#     "query": "%23KinderMorgan",
#     "tweet_volume": null,
#     "name": "#KinderMorgan",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2016-12-01T23:26:54Z",
#   "locations": [
#    {
#     "woeid": 23424775,
#     "name": "Canada"
#    }
#   ]
#  }
# ]
# Length of statuses 100
# Length of statuses 200
# Length of statuses 200
# [(u'RT', 136), (u'#Jio', 135), (u'\u0915\u0940', 49), (u'the', 46), (u'\u0915\u093e', 45), (u'@reliancejio:', 45), (u'#jio', 44), (u'\u092e\u0947\u0902', 43), (u'Jio', 42), (u'to', 42)]
#
# [(u'reliancejio', 50), (u'LambaAlka', 28), (u'kalyannn_', 7), (u'CNNnews18', 4), (u'tellychakkar', 4), (u'MouthShut', 4), (u'anirudhh_ani', 4), (u'MukeshAambani', 3), (u'abpnewstv', 3), (u'JioChat', 3)]
#
# [(u'Jio', 149), (u'jio', 45), (u'Jio50Million', 19), (u'JioOffer', 18), (u'jiooffer', 15), (u'MukeshAmbani', 13), (u'Facebook', 9), (u'Whatsapp', 9), (u'Skype', 8), (u'jioOffer', 8)]
#
# [1, 20, 101, 200, 1, 137, 79, 79, 93, 39, 44, 32, 79, 727, 22, 79, 101, 79, 101, 79, 79, 101, 46, 200, 5, 22, 101, 79, 79, 39, 79, 101, 1, 23, 37, 79, 79, 79, 79, 79, 79, 79, 8, 101, 200, 49, 35, 79, 79, 200, 727, 4, 83, 727, 134, 406, 200, 200, 200, 1, 134, 727, 3, 6, 103, 1, 137, 137, 727, 97, 103, 31, 95, 8, 35, 79, 39, 101, 83, 93, 97, 134, 95, 79, 8, 5, 101, 44, 727, 200, 137, 32, 93, 6, 1, 32, 200, 24, 34, 137, 137, 727, 1, 32, 32, 5, 1, 5, 20, 32, 20, 29, 4, 1, 4, 4, 4, 5, 23, 137, 1, 18, 200, 127, 101, 137, 35, 15, 101, 32, 48, 79, 200, 50, 38, 93]
# +---------------+-------+
# | Word          | Count |
# +---------------+-------+
# | RT            |   136 |
# | #Jio          |   135 |
# | की            |    49 |
# | the           |    46 |
# | का            |    45 |
# | @reliancejio: |    45 |
# | #jio          |    44 |
# | में           |    43 |
# | Jio           |    42 |
# | to            |    42 |
# +---------------+-------+
# +-------+-------------+----------------------------------------------------+
# | Count | Screen Name | Text                                               |
# +-------+-------------+----------------------------------------------------+
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# +-------+-------------+----------------------------------------------------+
# [1, 20, 101, 200, 1, 137, 79, 79, 93, 39, 44, 32, 79, 727, 22, 79, 101, 79, 101, 79, 79, 101, 46, 200, 5, 22, 101, 79, 79, 39, 79, 101, 1, 23, 37, 79, 79, 79, 79, 79, 79, 79, 8, 101, 200, 49, 35, 79, 79, 200, 727, 4, 83, 727, 134, 406, 200, 200, 200, 1, 134, 727, 3, 6, 103, 1, 137, 137, 727, 97, 103, 31, 95, 8, 35, 79, 39, 101, 83, 93, 97, 134, 95, 79, 8, 5, 101, 44, 727, 200, 137, 32, 93, 6, 1, 32, 200, 24, 34, 137, 137, 727, 1, 32, 32, 5, 1, 5, 20, 32, 20, 29, 4, 1, 4, 4, 4, 5, 23, 137, 1, 18, 200, 127, 101, 137, 35, 15, 101, 32, 48, 79, 200, 50, 38, 93]
# +---------------+-------+
# | Screen Name   | Count |
# +---------------+-------+
# | reliancejio   |    50 |
# | LambaAlka     |    28 |
# | kalyannn_     |     7 |
# | CNNnews18     |     4 |
# | tellychakkar  |     4 |
# | MouthShut     |     4 |
# | anirudhh_ani  |     4 |
# | MukeshAambani |     3 |
# | abpnewstv     |     3 |
# | JioChat       |     3 |
# +---------------+-------+
# +-------+-------------+----------------------------------------------------+
# | Count | Screen Name | Text                                               |
# +-------+-------------+----------------------------------------------------+
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# +-------+-------------+----------------------------------------------------+
# [1, 20, 101, 200, 1, 137, 79, 79, 93, 39, 44, 32, 79, 727, 22, 79, 101, 79, 101, 79, 79, 101, 46, 200, 5, 22, 101, 79, 79, 39, 79, 101, 1, 23, 37, 79, 79, 79, 79, 79, 79, 79, 8, 101, 200, 49, 35, 79, 79, 200, 727, 4, 83, 727, 134, 406, 200, 200, 200, 1, 134, 727, 3, 6, 103, 1, 137, 137, 727, 97, 103, 31, 95, 8, 35, 79, 39, 101, 83, 93, 97, 134, 95, 79, 8, 5, 101, 44, 727, 200, 137, 32, 93, 6, 1, 32, 200, 24, 34, 137, 137, 727, 1, 32, 32, 5, 1, 5, 20, 32, 20, 29, 4, 1, 4, 4, 4, 5, 23, 137, 1, 18, 200, 127, 101, 137, 35, 15, 101, 32, 48, 79, 200, 50, 38, 93]
# +--------------+-------+
# | Hashtag      | Count |
# +--------------+-------+
# | Jio          |   149 |
# | jio          |    45 |
# | Jio50Million |    19 |
# | JioOffer     |    18 |
# | jiooffer     |    15 |
# | MukeshAmbani |    13 |
# | Facebook     |     9 |
# | Whatsapp     |     9 |
# | Skype        |     8 |
# | jioOffer     |     8 |
# +--------------+-------+
# +-------+-------------+----------------------------------------------------+
# | Count | Screen Name | Text                                               |
# +-------+-------------+----------------------------------------------------+
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# | 727   | reliancejio | RT @reliancejio: 4/4 All existing #Jio customers   |
# |       |             | will get extended benefits of Jio Happy New Year   |
# |       |             | offer till 31 March 2017 on current SIMs:…         |
# +-------+-------------+----------------------------------------------------+
# [u'jyeee', u'Ceejaynatics', u'ikaayyy_', u'RafaellaaaMae', u'LoveKyana18', u'iiaamcamillee', u'kidamgos', u'shangxshang', u'asdfghjbl', u'Papagars__', u'josellexseraspi', u'annegabriellee_']
# 0.274266936299
# 0.294117647059
# 0.220264317181
# 19.78
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @Vindyne8: #TamTam Travels become a member today https://t.co/im6101TUhb receive #JIO tokens #travel #IMO #value https://t.co/ThjbUIqie6",
#  "is_quote_status": false,
#  "in_reply_to_status_id": null,
#  "id": 804465967057223681,
#  "favorite_count": 0,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 2309346044,
#     "indices": [
#      3,
#      12
#     ],
#     "id_str": "2309346044",
#     "screen_name": "Vindyne8",
#     "name": "Vindyne8"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      14,
#      21
#     ],
#     "text": "TamTam"
#    },
#    {
#     "indices": [
#      84,
#      88
#     ],
#     "text": "JIO"
#    },
#    {
#     "indices": [
#      96,
#      103
#     ],
#     "text": "travel"
#    },
#    {
#     "indices": [
#      104,
#      108
#     ],
#     "text": "IMO"
#    },
#    {
#     "indices": [
#      109,
#      115
#     ],
#     "text": "value"
#    }
#   ],
#   "urls": [
#    {
#     "url": "https://t.co/im6101TUhb",
#     "indices": [
#      52,
#      75
#     ],
#     "expanded_url": "http://tamtamtravels.com/jio-token/",
#     "display_url": "tamtamtravels.com/jio-token/"
#    }
#   ],
#   "media": [
#    {
#     "source_user_id": 2309346044,
#     "source_status_id_str": "804460987793473537",
#     "expanded_url": "https://twitter.com/Vindyne8/status/804460987793473537/photo/1",
#     "display_url": "pic.twitter.com/ThjbUIqie6",
#     "url": "https://t.co/ThjbUIqie6",
#     "media_url_https": "https://pbs.twimg.com/media/CyoFAJkXcAAWtf4.jpg",
#     "source_user_id_str": "2309346044",
#     "source_status_id": 804460987793473537,
#     "id_str": "804460983565643776",
#     "sizes": {
#      "large": {
#       "h": 91,
#       "resize": "fit",
#       "w": 88
#      },
#      "small": {
#       "h": 91,
#       "resize": "fit",
#       "w": 88
#      },
#      "medium": {
#       "h": 91,
#       "resize": "fit",
#       "w": 88
#      },
#      "thumb": {
#       "h": 88,
#       "resize": "crop",
#       "w": 88
#      }
#     },
#     "indices": [
#      116,
#      139
#     ],
#     "type": "photo",
#     "id": 804460983565643776,
#     "media_url": "http://pbs.twimg.com/media/CyoFAJkXcAAWtf4.jpg"
#    }
#   ]
#  },
#  "retweeted": false,
#  "coordinates": null,
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 1,
#  "id_str": "804465967057223681",
#  "favorited": false,
#  "retweeted_status": {
#   "contributors": null,
#   "truncated": false,
#   "text": "#TamTam Travels become a member today https://t.co/im6101TUhb receive #JIO tokens #travel #IMO #value https://t.co/ThjbUIqie6",
#   "is_quote_status": false,
#   "in_reply_to_status_id": null,
#   "id": 804460987793473537,
#   "favorite_count": 1,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       0,
#       7
#      ],
#      "text": "TamTam"
#     },
#     {
#      "indices": [
#       70,
#       74
#      ],
#      "text": "JIO"
#     },
#     {
#      "indices": [
#       82,
#       89
#      ],
#      "text": "travel"
#     },
#     {
#      "indices": [
#       90,
#       94
#      ],
#      "text": "IMO"
#     },
#     {
#      "indices": [
#       95,
#       101
#      ],
#      "text": "value"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/im6101TUhb",
#      "indices": [
#       38,
#       61
#      ],
#      "expanded_url": "http://tamtamtravels.com/jio-token/",
#      "display_url": "tamtamtravels.com/jio-token/"
#     }
#    ],
#    "media": [
#     {
#      "expanded_url": "https://twitter.com/Vindyne8/status/804460987793473537/photo/1",
#      "display_url": "pic.twitter.com/ThjbUIqie6",
#      "url": "https://t.co/ThjbUIqie6",
#      "media_url_https": "https://pbs.twimg.com/media/CyoFAJkXcAAWtf4.jpg",
#      "id_str": "804460983565643776",
#      "sizes": {
#       "large": {
#        "h": 91,
#        "resize": "fit",
#        "w": 88
#       },
#       "small": {
#        "h": 91,
#        "resize": "fit",
#        "w": 88
#       },
#       "medium": {
#        "h": 91,
#        "resize": "fit",
#        "w": 88
#       },
#       "thumb": {
#        "h": 88,
#        "resize": "crop",
#        "w": 88
#       }
#      },
#      "indices": [
#       102,
#       125
#      ],
#      "type": "photo",
#      "id": 804460983565643776,
#      "media_url": "http://pbs.twimg.com/media/CyoFAJkXcAAWtf4.jpg"
#     }
#    ]
#   },
#   "retweeted": false,
#   "coordinates": null,
#   "source": "<a href=\"https://about.twitter.com/products/tweetdeck\" rel=\"nofollow\">TweetDeck</a>",
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "804460987793473537",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "profile_use_background_image": false,
#    "default_profile_image": false,
#    "id": 2309346044,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "translator_type": "none",
#    "profile_text_color": "000000",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/660320354422775808/dtEITxFz_normal.jpg",
#    "profile_sidebar_fill_color": "000000",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/zKQj2DLr07",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "https://www.linkedin.com/in/john-ogden-34652bab?trk",
#        "display_url": "linkedin.com/in/john-ogden-\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 10862,
#    "profile_sidebar_border_color": "000000",
#    "id_str": "2309346044",
#    "profile_background_color": "000000",
#    "listed_count": 1047,
#    "is_translation_enabled": false,
#    "utc_offset": null,
#    "statuses_count": 33151,
#    "description": "Promotion, Marketing, Community building, Management for everything. Want us to work for you? Contact: vindyne8@gmail.com",
#    "friends_count": 8951,
#    "location": "Earth",
#    "profile_link_color": "1B95E0",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/660320354422775808/dtEITxFz_normal.jpg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2309346044/1474811359",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "Vindyne8",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 25218,
#    "name": "Vindyne8",
#    "notifications": false,
#    "url": "https://t.co/zKQj2DLr07",
#    "created_at": "Sat Jan 25 03:35:02 +0000 2014",
#    "contributors_enabled": false,
#    "time_zone": null,
#    "protected": false,
#    "default_profile": false,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Thu Dec 01 23:03:40 +0000 2016",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "extended_entities": {
#    "media": [
#     {
#      "expanded_url": "https://twitter.com/Vindyne8/status/804460987793473537/photo/1",
#      "display_url": "pic.twitter.com/ThjbUIqie6",
#      "url": "https://t.co/ThjbUIqie6",
#      "media_url_https": "https://pbs.twimg.com/media/CyoFAJkXcAAWtf4.jpg",
#      "id_str": "804460983565643776",
#      "sizes": {
#       "large": {
#        "h": 91,
#        "resize": "fit",
#        "w": 88
#       },
#       "small": {
#        "h": 91,
#        "resize": "fit",
#        "w": 88
#       },
#       "medium": {
#        "h": 91,
#        "resize": "fit",
#        "w": 88
#       },
#       "thumb": {
#        "h": 88,
#        "resize": "crop",
#        "w": 88
#       }
#      },
#      "indices": [
#       102,
#       125
#      ],
#      "type": "photo",
#      "id": 804460983565643776,
#      "media_url": "http://pbs.twimg.com/media/CyoFAJkXcAAWtf4.jpg"
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  "user": {
#   "follow_request_sent": false,
#   "has_extended_profile": false,
#   "profile_use_background_image": false,
#   "default_profile_image": false,
#   "id": 2309346044,
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "verified": false,
#   "translator_type": "none",
#   "profile_text_color": "000000",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/660320354422775808/dtEITxFz_normal.jpg",
#   "profile_sidebar_fill_color": "000000",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/zKQj2DLr07",
#       "indices": [
#        0,
#        23
#       ],
#       "expanded_url": "https://www.linkedin.com/in/john-ogden-34652bab?trk",
#       "display_url": "linkedin.com/in/john-ogden-\u2026"
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 10862,
#   "profile_sidebar_border_color": "000000",
#   "id_str": "2309346044",
#   "profile_background_color": "000000",
#   "listed_count": 1047,
#   "is_translation_enabled": false,
#   "utc_offset": null,
#   "statuses_count": 33151,
#   "description": "Promotion, Marketing, Community building, Management for everything. Want us to work for you? Contact: vindyne8@gmail.com",
#   "friends_count": 8951,
#   "location": "Earth",
#   "profile_link_color": "1B95E0",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/660320354422775808/dtEITxFz_normal.jpg",
#   "following": false,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2309346044/1474811359",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "screen_name": "Vindyne8",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 25218,
#   "name": "Vindyne8",
#   "notifications": false,
#   "url": "https://t.co/zKQj2DLr07",
#   "created_at": "Sat Jan 25 03:35:02 +0000 2014",
#   "contributors_enabled": false,
#   "time_zone": null,
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "possibly_sensitive": false,
#  "lang": "en",
#  "created_at": "Thu Dec 01 23:23:27 +0000 2016",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "extended_entities": {
#   "media": [
#    {
#     "source_user_id": 2309346044,
#     "source_status_id_str": "804460987793473537",
#     "expanded_url": "https://twitter.com/Vindyne8/status/804460987793473537/photo/1",
#     "display_url": "pic.twitter.com/ThjbUIqie6",
#     "url": "https://t.co/ThjbUIqie6",
#     "media_url_https": "https://pbs.twimg.com/media/CyoFAJkXcAAWtf4.jpg",
#     "source_user_id_str": "2309346044",
#     "source_status_id": 804460987793473537,
#     "id_str": "804460983565643776",
#     "sizes": {
#      "large": {
#       "h": 91,
#       "resize": "fit",
#       "w": 88
#      },
#      "small": {
#       "h": 91,
#       "resize": "fit",
#       "w": 88
#      },
#      "medium": {
#       "h": 91,
#       "resize": "fit",
#       "w": 88
#      },
#      "thumb": {
#       "h": 88,
#       "resize": "crop",
#       "w": 88
#      }
#     },
#     "indices": [
#      116,
#      139
#     ],
#     "type": "photo",
#     "id": 804460983565643776,
#     "media_url": "http://pbs.twimg.com/media/CyoFAJkXcAAWtf4.jpg"
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }
# [
#  "RT @Vindyne8: #TamTam Travels become a member today https://t.co/im6101TUhb receive #JIO tokens #travel #IMO #value https://t.co/ThjbUIqie6",
#  "RT @abpnewstv: 900 crore voice calls of #Jio customers were blocked to 3 largest incumbent operators displaying an anti-competitive behavio\u2026",
#  "RT @kalyannn_: Hope u all like it..\ud83d\ude0e\n\n#jioFan #Jio50Million #jioDigitalLife #jio #jio4g #jioOffer \ud83d\udcaa\ud83d\udcaa https://t.co/IPmzHjet8y",
#  "@MukeshAambani  hmm thik h 4 Months Aur use kr  Lete Hai.. Nahi to 1 January ko sim Fekne Wale the hm to  #jio",
#  "RT @reliancejio: #Jio data, voice, video will be absolutely free till 31 March 2017: Mukesh Ambani on Jio Happy New Year Offer https://t.co\u2026"
# ]
# [
#  "Vindyne8",
#  "abpnewstv",
#  "kalyannn_",
#  "MukeshAambani",
#  "reliancejio"
# ]
# [
#  "TamTam",
#  "JIO",
#  "travel",
#  "IMO",
#  "value"
# ]
# [
#  "RT",
#  "@Vindyne8:",
#  "#TamTam",
#  "Travels",
#  "become"
# ]
